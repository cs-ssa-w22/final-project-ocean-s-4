# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim

# %% [markdown]
# ### Load data source and fix data format

# %%
## load fips csv
fips = pd.read_csv("fips2county.tsv", sep='\t', dtype={'CountyFIPS_3': 'string'} )
fips['fips_code']= fips['CountyFIPS'].astype(str)
# fix data format
fips.loc[fips['fips_code'].str.len() == 4, ['fips_code']] = '0' + fips['fips_code'][fips['fips_code'].str.len() == 4]
fips.fips_code
# Out:
# 0       01001
# 1       01003
# 2       01005
# 3       01007
# 4       01009
#         ...
# 3137    56037
# 3138    56039
# 3139    56041
# 3140    56043
# 3141    56045
# Name: fips_code, Length: 3142, dtype: object

# %% [markdown]
# ### Load school data and clean location data

# %%
school = 'data/Brown University' # change to your school's name
df = pd.read_csv(school + '_clean.csv')

# %%
# replace wrong locations(string 'connections' in them) to nulls
no_value = df.current_location.str.contains('connections') 
df.loc[no_value,'current_location'] = np.NAN

# remove some strings not identified by geocode (!you can add more depending on your data)
l = ['Metropolitan','Area', 'Township of', 'Region', 'Greater', 'Metroplex', 'District']
df['current_location'] = df['current_location'].str.replace('|'.join(l), '', regex=True)

geolocator = Nominatim(user_agent="course_project")

# %%
# generate a dictionary mapping unique locations to corresponding coordinates (4 mins)
latitude = {}
longitude = {}
state = {}
county = {}
city = {}
unique_locs = df.current_location.unique()
for loc in unique_locs:
    location = geolocator.geocode(loc, timeout = 600,addressdetails=True)
    if pd.isna(location) or pd.isna(loc):
        latitude[loc] = np.NAN
        longitude[loc] = np.NAN
        state[loc] = np.NAN
        county[loc] = np.NAN
        city[loc] = np.NAN
    else:
        latitude[loc] = location.latitude
        longitude[loc] = location.longitude
        try:
            state[loc] = location.raw['address']['state']
        except:
            state[loc] = np.NAN
        try:
            county[loc] = location.raw['address']['county'].rsplit(' ',1)[0]
        except:
            county[loc] = np.NAN
        try:
            city[loc] = location.raw['address']['city']
        except:
            city[loc] = np.NAN

# %%
df['latitude'] = df.apply(lambda row: latitude[row.current_location], axis =1)
df['longitude'] = df.apply(lambda row: longitude[row.current_location], axis =1)
df['state'] = df.apply(lambda row: state[row.current_location], axis =1)
df['county'] = df.apply(lambda row: county[row.current_location], axis =1)
df['city'] = df.apply(lambda row: city[row.current_location], axis =1)

# %%
def mapping(row):
    ''' map state-county to fips code
    '''
    if row[['county','state']].notnull().all():
        x = fips[(fips.CountyName==row.county) & (fips.StateName==row.state)]['fips_code'].values.tolist()
        if x !=[]:
            return str(x[0])
    else:
        try:
            x = fips[(fips.CountyName==row.city) & (fips.StateName==row.state)]['fips_code'].values.tolist()
            if x !=[]:
                return str(x[0])
        except:
            pass   
    return np.NAN

# %%
df['fips'] = df.apply(mapping, axis=1)
df['fips']  = df['fips'] .astype(str)

# %%
df = df.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dell\Desktop\30122\final-project-ocean-s-4\data analysis code\add_fips.ipynb Cell 14' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/30122/final-project-ocean-s-4/data%20analysis%20code/add_fips.ipynb#ch0000013?line=0'>1</a> df = df.drop(columns=['Unnamed: 0'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4773'>4774</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4774'>4775</a> def drop(
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4775'>4776</a>     self,
#    (...)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4782'>4783</a>     errors: str = "raise",
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4783'>4784</a> ):
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4784'>4785</a>     """
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4785'>4786</a>     Drop specified labels from rows or columns.
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4786'>4787</a>
#    (...)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4903'>4904</a>             weight  1.0     0.8
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4904'>4905</a>     """
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4905'>4906</a>     return super().drop(
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4906'>4907</a>         labels=labels,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4907'>4908</a>         axis=axis,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4908'>4909</a>         index=index,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4909'>4910</a>         columns=columns,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4910'>4911</a>         level=level,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4911'>4912</a>         inplace=inplace,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4912'>4913</a>         errors=errors,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4913'>4914</a>     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4150, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4147'>4148</a> for axis, labels in axes.items():
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4148'>4149</a>     if labels is not None:
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4149'>4150</a>         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4151'>4152</a> if inplace:
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4152'>4153</a>     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4185, in NDFrame._drop_axis(self, labels, axis, level, errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4182'>4183</a>         new_axis = axis.drop(labels, level=level, errors=errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4183'>4184</a>     else:
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4184'>4185</a>         new_axis = axis.drop(labels, errors=errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4185'>4186</a>     result = self.reindex(**{axis_name: new_axis})
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4187'>4188</a> # Case for non-unique axis
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4188'>4189</a> else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6017, in Index.drop(self, labels, errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6014'>6015</a> if mask.any():
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6015'>6016</a>     if errors != "ignore":
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6016'>6017</a>         raise KeyError(f"{labels[mask]} not found in axis")
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6017'>6018</a>     indexer = indexer[~mask]
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6018'>6019</a> return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.fips
# Out:
# 0       39049
# 1       36061
# 2       06073
# 3       06081
# 4       04013
#         ...
# 2427    06075
# 2428    06075
# 2429    36061
# 2430      nan
# 2431    17031
# Name: fips, Length: 2432, dtype: object

# %%
df.latitude = np.round(df.latitude, 6)
df.longitude = np.round(df.longitude, 6)

# %%
df[df.fips!= 'nan']
# Out:
#                                  current_location  \
# 0                     Dublin, Ohio, United States
# 1                                 New York City
# 2     San Diego County, California, United States
# 3                              San Francisco Bay
# 4                    Mesa, Arizona, United States
# ...                                           ...
# 2426                Houston, Texas, United States
# 2427     San Francisco, California, United States
# 2428     San Francisco, California, United States
# 2429            New York, New York, United States
# 2431             Chicago, Illinois, United States
#
#                                            current_work  \
# 0     Director, Cyber Security Operations & Incident...
# 1     Vice President of Development at TRITEC Real E...
# 2      Strategic Advisor at Ionis Pharmaceuticals, Inc.
# 3     Strategic Enterprise Solutions, International ...
# 4     Senior Director, Global Enterprise Risk Manage...
# ...                                                 ...
# 2426  Vice President , Women's Health and Genomics a...
# 2427  Strategic Partnerships Manager, US Retail at G...
# 2428  Strategic Partnerships Manager, US Retail at G...
# 2429                               Product Lead at Zoom
# 2431              Director - Asset Management at LivCor
#
#                                           previous_work  \
# 0                   Cyber Security Manager at Capgemini
# 1     Development Analyst at TRITEC Real Estate Comp...
# 2     Vice President Of Business Development and All...
# 3     Partnerships & Sales, Corporate Solutions at Y...
# 4     Director of Global Supply Chain Planning / New...
# ...                                                 ...
# 2426  Senior Director, Medical Policy and Operations...
# 2427  Strategy & Planning Manager, Global Business S...
# 2428  Strategy & Planning Manager, Global Business S...
# 2429                     Senior Product Manager at Zoom
# 2431  Assistant Vice President - Asset Management at...
#
#                                        latest_Education  \
# 0                                      Brown University
# 1                                 Georgetown University
# 2                                             1999–2001
# 3                                      Brown University
# 4       University of Pennsylvania - The Wharton School
# ...                                                 ...
# 2426            Department of Health and Human Services
# 2427                                   Brown University
# 2428                                   Brown University
# 2429                                   Brown University
# 2431  Northwestern University - Kellogg School of Ma...
#
#                                                   major     search_school  \
# 0     Computer Science, Computer Networking and Secu...  Brown University
# 1                               Real Estate Development  Brown University
# 2                                 Healthcare Management  Brown University
# 3     Entrepreneurship, Organizations, and Social Ju...  Brown University
# 4                       Strategic Management & Planning  Brown University
# ...                                                 ...               ...
# 2426                                                NaN  Brown University
# 2427  Commerce, Organization, and Entrepreneurship -...  Brown University
# 2428                                                NaN  Brown University
# 2429                                                NaN  Brown University
# 2431                              Real Estate & Finance  Brown University
#
#        latitude   longitude       state     county           city   fips
# 0     40.099229  -83.114077        Ohio   Franklin            NaN  39049
# 1     40.712728  -74.006015    New York        NaN       New York  36061
# 2     32.963784 -116.770628  California  San Diego            NaN  06073
# 3     37.714029 -122.307794  California  San Mateo            NaN  06081
# 4     33.415112 -111.831479     Arizona   Maricopa           Mesa  04013
# ...         ...         ...         ...        ...            ...    ...
# 2426  29.758938  -95.367697       Texas     Harris        Houston  48201
# 2427  37.779026 -122.419906  California        NaN  San Francisco  06075
# 2428  37.779026 -122.419906  California        NaN  San Francisco  06075
# 2429  40.712728  -74.006015    New York        NaN       New York  36061
# 2431  41.875562  -87.624421    Illinois       Cook        Chicago  17031
#
# [2016 rows x 12 columns]

# %%
## save to a new csv file!!!
df.to_csv(school + '_with_fips.csv')

# %%
# bugfix (optional)
#check a specific location
location = geolocator.geocode('Frankfurt Rhine', timeout = 600)
location
# Out:
# Location(Frankfurter Straße, Urdenbach, Stadtbezirk 9, Düsseldorf, Nordrhein-Westfalen, 40593, Deutschland, (51.1549523, 6.8854454, 0.0))

# %%
#check NAN values and revise current locations to be searchable (change/add more strings to remove in l)
df[(df.coordinate.isna()) & (df.current_location.notna())]
# Out:
#                                        current_location  \
# 337    Greenville-Spartanburg-Anderson, South Carolina
# 548                              Frankfurt Rhine-Main
# 1001  Ezana is a startup entrepreneur currently prom...
# 1013  Laila Mickelwait is the Founder and CEO of the...
# 1782                              CEO at Cyphen Limited
#
#                                            current_work  \
# 337   President/Owner, Financial Advisor, CFP®, CRPC...
# 548   Head of Banking and Partner Strategy and Execu...
# 1001                                   CEO at Afri Kash
# 1013                Founder/CEO at Justice Defense Fund
# 1782                              CEO at Cyphen Limited
#
#                                           previous_work  \
# 337   Vice President, Financial Advisor, CFP®, CRPC®...
# 548                   Senior Adviser at Holland FinTech
# 1001       Service Management Officer at United Nations
# 1013               Founder at New Reality International
# 1782                                                NaN
#
#                                        latest_Education  \
# 337   University of South Carolina - The Moore Schoo...
# 548               University of   California, Riverside
# 1001                University of California, Riverside
# 1013                  University of Southern California
# 1782                                  Peking University
#
#                                major                        search_school  \
# 337                Brazil/Portuguese  University of California, Riverside
# 548   German Language and Literature  University of California, Riverside
# 1001               Political Science  University of California, Riverside
# 1013                Public Diplomacy  University of California, Riverside
# 1782                            国际经济  University of California, Riverside
#
#      coordinate state county city  fips
# 337         NaN   NaN    NaN  NaN  <NA>
# 548         NaN   NaN    NaN  NaN  <NA>
# 1001        NaN   NaN    NaN  NaN  <NA>
# 1013        NaN   NaN    NaN  NaN  <NA>
# 1782        NaN   NaN    NaN  NaN  <NA>
