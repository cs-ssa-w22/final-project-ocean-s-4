# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get('http://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0] 
password = lines[1]

# auto log in my linkedin account
elementID = browser.find_element_by_id('username')
elementID.send_keys(username)
elementID = browser.find_element_by_id('password')
elementID.send_keys(password)
elementID.submit()
# Out:
# WDM        - INFO     -
#
# ====== WebDriver manager ======
# WDM        - INFO     - ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# WDM        - INFO     - Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# WDM        - INFO     - Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/ning/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# WDM        - INFO     - Driver [/Users/ning/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# <ipython-input-35-4480227a8784>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-35-4480227a8784>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elementID = browser.find_element_by_id('username')
# ...

# %%
# school search page - sales navigator
rank_72 = ''
rank_49 = ''
rank_84 = ''
rank_02 = 'https://www.linkedin.com/sales/search/people?keywords=&rsLogId=1299546586&schoolIncluded=18483&searchSessionId=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D'
rank_18 = ''

# %% [markdown]
# 下面试图探索了一些自动把网页存成html格式保存到本地的方法，但是只能保存为单个html文件，无法保存complete webpage。

# %%
# # Method 1: can only save the html version of linkedin page
# # reference: https://www.lambdatest.com/blog/how-to-get-page-source-in-selenium-webdriver/
# browser.get(rank_02)
# pageSource = browser.page_source
# time.sleep(2)
# fileToWrite = open('rank02_p1.html','w')
# fileToWrite.write(pageSource)
# fileToWrite.close()
# fileToRead = open('rank02_p1.html', 'r')
# print(fileToRead.read())
# fileToRead.close()
# Out:
# <html lang="en" class="artdeco osx"><head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>Sales Navigator</title>
#     <meta name="description" content="">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
#
#     <style>
#       /* stylelint-disable */
#       .initial-load-animation {
#         padding-top: 96px;
#         width: 200px;
#         margin: 0 auto;
#         transform: scale(1);
#         transition: transform .5s ease;
#       }
#       .salesnav-image {
#         background-image: url('https://static-exp1.licdn.com/sc/h/v4ody32j7r2zqlkj9lxg96x3');
#         height: 55px;
#         width: 55px;
#         margin: 0 auto;
#         margin-bottom: 32px;
#         transform: translate(0, 0);
#         opacity: 1;
#         transition: all .5s ease-out;
#       }
#       .loading-bar {
#         width: 130px;
#         height: 2px;
#         margin: 0 auto;
# ...

# %%
# # Method 2: takes too long time to run, haven't run successfully yet
# from pywebcopy import save_webpage
# url = rank_02
# download_folder = '/Users/ning/Desktop/Uchicago/Winter 2022/30122_Application/final-project-ocean-s-4/school_profile_url_lists/rank02/'
# kwargs = {'bypass_robots': True, 'project_name': 'linkedin-scraping'}
# save_webpage(url, download_folder, **kwargs)
# Out:
# pywebcopy.configs - INFO     - Got response 200 from https://www.linkedin.com/robots.txt
# /opt/anaconda3/lib/python3.8/site-packages/pywebcopy/webpage.py:82: UserWarning: Global Configuration is not setup. You can ignore this if you are going manual.This is just one time warning regarding some unexpected behavior.
#   warnings.warn(
# pywebcopy.configs - WARNING  - Forcefully Accessing restricted website part https://www.linkedin.com/sales/search/people?keywords=&rsLogId=1299546586&schoolIncluded=18483&searchSessionId=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D
# pywebcopy.configs - INFO     - Got response 200 from https://www.linkedin.com/sales/search/people?keywords=&rsLogId=1299546586&schoolIncluded=18483&searchSessionId=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D
# webpage    - INFO     - Starting save_complete Action on url: ['https://www.linkedin.com/sales/search/people?keywords=&rsLogId=1299546586&schoolIncluded=18483&searchSessionId=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D']
# ...

# %%
# # Method 3: can only save the html version of linkedin page
#  url = requests.get(rank_02)
# url_txt = url.text
# with open(r"/Users/ning/Desktop/Uchicago/Winter 2022/30122_Application/final-project-ocean-s-4/school_profile_url_lists/rank02/rank02_1.html", "w", encoding="UTF-8") as f:
#     f.write(url_txt)
# f.close
# Out:
# <function TextIOWrapper.close()>

# %%
height = 0
for i in range(10):
    height += 1000
    time.sleep(1)
    strheight = str(height)
    browser.execute_script(f"window.scrollTo(0, {strheight})")

# %%
with open('/Users/ning/Desktop/Uchicago/Winter 2022/30122_Application/final-project-ocean-s-4/school_profile_url_lists/rank02/3.html') as fp:
   soup_test = BeautifulSoup(fp, 'html.parser')

# %%
soup_test.find_all('dt', class_='result-lockup__name')
profile = []
for links in soup_test.find_all('dt', class_='result-lockup__name'):
    alst = links.find_all('a')
    profile.extend([e['href'] for e in alst])

profile
# Out:
# ['https://www.linkedin.com/sales/people/ACwAAAMTRg8Bge9uOtVB-ibHDv2VRwLEXXW_3DA,NAME_SEARCH,jjb9?_ntb=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D',
#  'https://www.linkedin.com/sales/people/ACwAAAQMvLABMEZE3BizwARb8yE1l6QsICilmCw,NAME_SEARCH,UGf2?_ntb=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D',
#  'https://www.linkedin.com/sales/people/ACwAAAFpMAABD1pSPiW2GeNQ9Yp26_ik7CVuw_M,NAME_SEARCH,WkSK?_ntb=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D',
#  'https://www.linkedin.com/sales/people/ACwAABpb_hMBDYg3OHbLMj4uVDrsYhf2dVu_kA8,NAME_SEARCH,v_95?_ntb=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D',
#  'https://www.linkedin.com/sales/people/ACwAAC2LtSoBy5KdJH_uGcr_V0MDPXcJK-oWh7g,NAME_SEARCH,drfe?_ntb=9KyDNC%2BwTuWQ29V%2BKy%2B1CA%3D%3D']
