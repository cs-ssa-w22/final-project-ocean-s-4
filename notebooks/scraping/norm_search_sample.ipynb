# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
browser = webdriver.Chrome('/Users/zss/Desktop/Application_2/final_project/chromedriver')
browser.get('http://www.linkedin.com/uas/login')
# Out:
# /var/folders/f2/41ckpyln3370bz1wf7vdknb80000gn/T/ipykernel_20637/527759107.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('/Users/zss/Desktop/Application_2/final_project/chromedriver')

# %%
link = 'https://www.linkedin.com/in/jiehan-liu-3155b7190/'
browser.get(link)

# %%
scroll_pause_time = 5

last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    browser.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    
    time.sleep(scroll_pause_time)
    
    new_height = browser.execute_script('return document.body.scrollHeight')
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
src
# Out:
# '<html lang="en" class="theme theme--mercado artdeco osx"><head>\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>Jiehan Liu | LinkedIn</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="service" content="voyager-web">\n    <meta name="theme-color" content="#ffffff" id="theme-color-meta-tag">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <meta name="baseCDNUrl" content
# ...

# %%
soup = BeautifulSoup(src, 'lxml')

# %%
soup
# Out:
# <html class="theme theme--mercado artdeco osx" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Jiehan Liu | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
name_div = soup.find('div', {'class': 'mt2 relative'})
text = name_div.get_text()

# %%
text = text.split('\n')
result = []
for t in text:
    if t.strip():
        result.append(t.strip())

# %%
result
# Out:
# ['Jiehan Liu',
#  '1st degree connection',
#  '1st',
#  'Uchicago Political Science',
#  'University of Chicago',
#  'Greater Chicago Area',
#  'Contact info']

# %%
name = result[0]
profile_title = result[3]
loc = result[5]

# %%
name
# Out:
# 'Jiehan Liu'

# %%
profile_title
# Out:
# 'Uchicago Political Science'

# %%
loc
# Out:
# 'Greater Chicago Area'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)

# %%
info
# Out:
# ['https://www.linkedin.com/in/jiehan-liu-3155b7190/',
#  'Jiehan Liu',
#  'Uchicago Political Science',
#  'Greater Chicago Area']

# %%
link_ppl = 'https://www.linkedin.com/search/results/people/?geoUrn=%5B%2290000014%22%5D&industry=%5B%226%22%5D&keywords=data%20science&origin=GLOBAL_SEARCH_HEADER&profileLanguage=%5B%22en%22%5D&sid=eUj'

# %%
browser = webdriver.Chrome('/Users/zss/Desktop/Application_2/final_project/chromedriver')
browser.get(link_ppl)
# Out:
# /var/folders/f2/41ckpyln3370bz1wf7vdknb80000gn/T/ipykernel_20637/3481149183.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('/Users/zss/Desktop/Application_2/final_project/chromedriver')

# %%
ppl = browser.page_source
ppl
# Out:
# '<html lang="en" class="theme theme--mercado artdeco osx"><head>\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>"data science" | Search | LinkedIn</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="service" content="voyager-web">\n    <meta name="theme-color" content="#ffffff" id="theme-color-meta-tag">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <meta name="baseCD
# ...

# %%
soup_ppl = BeautifulSoup(ppl)
soup_ppl
# Out:
# <html class="theme theme--mercado artdeco osx" lang="en"><head>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>"data science" | Search | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...

# %%
sublink = soup_ppl.find('a', {'class': 'app-aware-link'})
sublink.get('href')
# Out:
# 'https://www.linkedin.com/in/desenliu?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAZEBZsBtOvwN1pkLYXpPB6T790dCAsR4QI'
